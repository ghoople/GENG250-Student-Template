# %% [markdown]
# # Homework 6 - Electricity Sales

# %% [markdown]
# Download the EIA Sales of Electricity to Ultimate Customers [zip file](https://drive.google.com/open?id=1i6PwUdnGWafu4za_GMzb-42LL7SrlJBJ&usp=drive_fs) You'll need to unzip the file (or extract it) and then move it into your VS Code folder.

# %%
# Import your libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Allow for interactive plotting in Jupyter notebooks, comment out to turn this off. 
# The % sign is a Jupyter magic command that enables the use of widgets in the notebook.
# This requires installing the ipympl package.
# %matplotlib widget

# %%
# Import the dataset
sales = pd.read_excel(#Add your file path here, e.g., 'data/sales_data.xlsx')
print(sales.head())

# %%
# Does this data look right? I don't think so! There are a few rows of information
# before the actual data starts, and the header is not in the first row.
# Ask AI how you can modify the code above to handle this situation. 
# Add your solution below 

sales = 
print(sales.head())

# %%
# Now you'll create a line plot showing the electricity sales over time

plt.figure()  # Create a new figure
sns.lineplot(x="Period", y="Residential", label = "Residential", data=sales)

# To add additional lines for other categories, you can use the same sns.lineplot function 
# and simply modify the 'y' parameter to the respective column names.


# Add code to add a title, xlable, and ylabel to the plot



plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Create a line plot showing the electricity sales over time
# ----> 3 plt.figure()  # Create a new figure
#       4 sns.lineplot(x="Period", y="Residential", label = "Residential", data=sales)
#       5 sns.lineplot(x="Period", y="Commercial", label = "Commercial", data=sales)
#
# NameError: name 'plt' is not defined
